# %%
import pandas as pd
import tensorflow as tf
import numpy as np
import sys
import os

# %%
data = pd.read_csv('../data/train/gym_members_exercise_tracking_train.csv')

# %%
data.head()
# Out:
#    Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0   20    Male         55.0        1.60      172      168           67
# 1   39  Female         60.6        1.65      162      167           63
# 2   54  Female         75.6        1.72      194      154           60
# 3   24  Female         58.9        1.51      187      157           68
# 4   20  Female         65.4        1.52      185      127           50
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 0                      1.12           1035.0         Yoga            24.0
# 1                      0.92            768.0         HIIT            27.6
# 2                      0.97            672.0       Cardio            26.4
# 3                      1.04            816.0       Cardio            31.7
# 4                      1.03            654.0         Yoga            28.0
#
#    Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# 0                    3.2                              4                 2
# 1                    1.7                              3                 1
# 2                    1.9                              3                 1
# 3                    2.5                              2                 1
# 4                    2.2                              4                 2
#
#      BMI
# 0  21.48
# 1  22.26
# 2  25.55
# 3  25.83
# 4  28.31

# %%
# Add the parent directory to the path
sys.path.append(os.path.abspath('..'))

from src.preprocessing import preprocess_data

df = preprocess_data(data, 'experience_level')

df.head()
df['experience_level'].unique()
# Out:
# No missing values found, returning original dataframe
# Categorical columns: ['Gender', 'Workout_Type']
# The max imbalance occurs on class 2 at 11.07% greater than the next greatest class
# array([2, 1, 3])

# %%
from src.model import train_model
from src.preprocessing import test_val_train_split

X_train, y_train, X_test, y_test, X_val, y_val = test_val_train_split(df, 'experience_level')

model = train_model(X_train, y_train, X_val, y_val)
# Out:
# Target values transformed from 1-3 to 0-2
# Value mapping: {np.int64(1): np.int64(0), np.int64(2): np.int64(1), np.int64(3): np.int64(2)}
# Epoch 1/100
# /Users/apple/Documents/dev/ALU/2025-01/MLOP_Summative/myenv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5342 - loss: 1.6328 - val_accuracy: 0.7323 - val_loss: 1.3818
# Epoch 2/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7747 - loss: 1.2979 - val_accuracy: 0.8661 - val_loss: 1.1198
# Epoch 3/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8861 - loss: 1.0688 - val_accuracy: 0.8819 - val_loss: 0.9567
# Epoch 4/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9102 - loss: 0.9112 - val_accuracy: 0.8661 - val_loss: 0.8550
# Epoch 5/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8914 - loss: 0.8033 - val_accuracy: 0.8976 - val_loss: 0.7545
# Epoch 6/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8838 - loss: 0.7395 - val_accuracy: 0.8819 - val_loss: 0.7072
# Epoch 7/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9126 - loss: 0.6605 - val_accuracy: 0.8819 - val_loss: 0.6640
# Epoch 8/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8999 - loss: 0.6273 - val_accuracy: 0.8819 - val_loss: 0.6202
# Epoch 9/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9131 - loss: 0.5751 - val_accuracy: 0.8898 - val_loss: 0.5838
# Epoch 10/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9150 - loss: 0.5441 - val_accuracy: 0.8661 - val_loss: 0.5589
# Epoch 11/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9298 - loss: 0.5071 - val_accuracy: 0.8583 - val_loss: 0.5439
# Epoch 12/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9393 - loss: 0.4741 - val_accuracy: 0.9055 - val_loss: 0.5018
# Epoch 13/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9181 - loss: 0.4744 - val_accuracy: 0.8268 - val_loss: 0.5256
# Epoch 14/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8929 - loss: 0.4543 - val_accuracy: 0.8976 - val_loss: 0.4634
# Epoch 15/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9257 - loss: 0.4280 - val_accuracy: 0.8898 - val_loss: 0.4531
# Epoch 16/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9173 - loss: 0.4057 - val_accuracy: 0.9055 - val_loss: 0.4297
# Epoch 17/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9129 - loss: 0.3993 - val_accuracy: 0.8661 - val_loss: 0.4417
# Epoch 18/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9182 - loss: 0.3751 - val_accuracy: 0.8661 - val_loss: 0.4243
# Epoch 19/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.